# %% [markdown]
# ## Import Libraries and Set Up Environment

# %%
# Import necessary libraries
import warnings
import torch
import numpy as np
import random
from torch.utils.data import Subset
from sklearn.model_selection import KFold
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping, Timer
from pytorch_lightning import Trainer
from fukui_net.utils.utils import MoleculeDataModule, initialize_cuda, evaluate_model_full
from fukui_net.utils.train import MoleculeModel, Model, CrossValDataModule
from lion_pytorch import Lion

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# Initialize CUDA settings
initialize_cuda()

# Suppress unnecessary warnings
warnings.filterwarnings("ignore", category=UserWarning, module="pytorch_lightning.trainer.connectors.data_connector")
warnings.filterwarnings("ignore", category=UserWarning, module="lightning_fabric.plugins.environments.slurm")

# Ensure deterministic behavior in CUDA operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# cuda True
# NVIDIA GeForce RTX 3090

# %% [markdown]
# ### Load Dataset and Define Model Parameters

# %%
# Load dataset
dataset = torch.load(f'../data/processed/QM_137k.pt')
in_features = dataset[0].x.shape[1]
out_features = 1
edge_attr_dim = dataset[0].edge_attr.shape[1]

# Data module settings
batch_size = 1024 
num_workers = 8  

# Define the model architecture parameters
preprocess_hidden_features = [128] * 9
postprocess_hidden_features = [128, 128]
cheb_hidden_features = [128, 128]
K = [10, 16]
cheb_normalization = ['sym', 'sym']

dropout_rates = [0.0] * (len(preprocess_hidden_features) + len(postprocess_hidden_features))
activation_fns = [torch.nn.PReLU] * (len(preprocess_hidden_features) + len(postprocess_hidden_features))
use_batch_norm = [True] * (len(preprocess_hidden_features) + len(postprocess_hidden_features))

# Optimizer settings
optimizer_class = Lion
learning_rate = 2.2e-5
weight_decay = 3e-5
step_size = 80
gamma = 0.2
metric = 'rmse'

# %% [markdown]
# ## Instantiate Model Backbone

# %%
# Instantiate model backbone
backbone = Model(
    atom_in_features=in_features,
    edge_attr_dim=edge_attr_dim,
    preprocess_hidden_features=preprocess_hidden_features,
    cheb_hidden_features=cheb_hidden_features,
    K=K,
    cheb_normalizations=cheb_normalization,
    dropout_rates=dropout_rates,
    activation_fns=activation_fns,
    use_batch_norm=use_batch_norm,
    postprocess_hidden_features=postprocess_hidden_features,
    out_features=out_features
)

# %%
print("Model Backbone Architecture:\n", backbone)
# Out:
# Model Backbone Architecture:
#  Model(
#   (atom_preprocess): ModuleList(
#     (0): AtomEdgeInteraction(
#       (interaction): KANLinear(
#         (base_activation): SiLU()
#       )
#       (activation): ReLU()
#       (batch_norm): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.0, inplace=False)
#       (residual): Linear(in_features=133, out_features=128, bias=True)
#     )
#     (1-8): 8 x Sequential(
#       (0): KANLinear(
#         (base_activation): SiLU()
#       )
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#       (3): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (cheb_convolutions): ModuleList(
#     (0): ChebConv(128, 128, K=10, normalization=sym)
#     (1): ChebConv(128, 128, K=16, normalization=sym)
#   )
#   (postprocess): ModuleList(
#     (0-1): 2 x Sequential(
#       (0): KANLinear(
#         (base_activation): SiLU()
#       )
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): PReLU(num_parameters=1)
#       (3): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (output_layer): KANLinear(
#     (base_activation): SiLU()
#   )
# )

# %% [markdown]
# ## K-Fold cross-validation setup

# %%
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
data_indices = list(range(len(dataset)))

fold_results = []
best_val_loss = float('inf')
best_model = None

# %% [markdown]
# ## Training Loop for Cross-Validation

# %%
# Perform K-Fold cross-validation
for fold, (train_index, val_index) in enumerate(kf.split(data_indices)):
    print(f"Fold {fold+1}/{n_splits}")

    # Create data subsets for this fold
    train_subset = Subset(dataset, train_index)
    val_subset = Subset(dataset, val_index)
    data_module = CrossValDataModule(train_subset, val_subset, batch_size=batch_size, num_workers=num_workers)

    # Initialize model for this fold
    model = MoleculeModel(
        model_backbone=backbone,
        optimizer_class=optimizer_class,
        learning_rate=learning_rate,
        weight_decay=weight_decay,
        step_size=step_size,
        gamma=gamma,
        batch_size=batch_size,
        metric=metric
    )

    # Callbacks for model checkpointing and early stopping
    checkpoint_callback = ModelCheckpoint(monitor='val_loss', mode='min', save_top_k=1, verbose=True, dirpath='.', filename='best_model')
    early_stop_callback = EarlyStopping(monitor='val_loss', patience=5, verbose=True, mode='min')
    timer = Timer()
    logger = pl.loggers.TensorBoardLogger('../reports/tb_logs', name=f'KAN_fold_{fold+1}')

    # Trainer configuration
    trainer = Trainer(
        max_epochs=100,
        enable_checkpointing=True,
        callbacks=[early_stop_callback, timer, checkpoint_callback],
        enable_progress_bar=False,
        logger=logger,
        accelerator='gpu',
        devices=1
    )

    # Train the model
    trainer.fit(model, data_module)

    # Get validation loss
    val_loss = trainer.callback_metrics["val_loss"].item()
    fold_results.append(val_loss)

    # Save the best model based on validation loss
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model


    seconds = timer.time_elapsed()
    h, m, s = int(seconds // 3600), int((seconds % 3600) // 60), int(seconds % 60)
    print(f"Training time for fold {fold+1}: {h}:{m:02d}:{s:02d}")
# Out:
# Fold 1/5
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Missing logger folder: tb_logs/KAN_fold_1
# /home/nikolenko/.local/lib/python3.10/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:653: Checkpoint directory /home/nikolenko/work/fukui_index_prediction/notebooks exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type  | Params
# -----------------------------------------
# 0 | model_backbone | Model | 2.3 M
# -----------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.096     Total estimated model params size (MB)
# /home/nikolenko/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 43
#      40 trainer.fit(model, data_module)
#      42 # Get validation loss
# ---> 43 val_loss = trainer.callback_metrics["val_loss"].item()
#      44 fold_results.append(val_loss)
#      46 # Save the best model based on validation loss
#
# KeyError: 'val_loss'

# %% [markdown]
# ## Cross-Validation Results and Final Model Save

# %%
# Print cross-validation results
print("Cross-validation results:")
for i, val_loss in enumerate(fold_results):
    print(f"Fold {i+1}: Validation error (RMSE) = {val_loss:.4f}")

mean_val_loss = sum(fold_results) / len(fold_results)
print(f"Average validation error (RMSE): {mean_val_loss:.4f}")

# Save the final best model

torch.save("../model/final_best_model.ckpt")
print(f"Final best model saved!")
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: tb_logs/KAN_fold_1
# /home/nikolenko/.local/lib/python3.10/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:653: Checkpoint directory /home/nikolenko/work/gat exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type  | Params
# -----------------------------------------
# 0 | model_backbone | Model | 2.3 M
# -----------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.096     Total estimated model params size (MB)
# Fold 1/5
# /home/nikolenko/.local/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Metric val_loss improved. New best score: 0.205
# Epoch 0, global step 1: 'val_loss' reached 0.20457 (best 0.20457), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.204
# Epoch 1, global step 2: 'val_loss' reached 0.20401 (best 0.20401), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.204
# Epoch 2, global step 3: 'val_loss' reached 0.20357 (best 0.20357), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.203
# Epoch 3, global step 4: 'val_loss' reached 0.20317 (best 0.20317), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.203
# Epoch 4, global step 5: 'val_loss' reached 0.20282 (best 0.20282), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.202
# Epoch 5, global step 6: 'val_loss' reached 0.20249 (best 0.20249), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.202
# Epoch 6, global step 7: 'val_loss' reached 0.20217 (best 0.20217), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.202
# Epoch 7, global step 8: 'val_loss' reached 0.20189 (best 0.20189), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.202
# Epoch 8, global step 9: 'val_loss' reached 0.20163 (best 0.20163), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.201
# Epoch 9, global step 10: 'val_loss' reached 0.20140 (best 0.20140), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.201
# Epoch 10, global step 11: 'val_loss' reached 0.20119 (best 0.20119), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.201
# Epoch 11, global step 12: 'val_loss' reached 0.20099 (best 0.20099), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.201
# Epoch 12, global step 13: 'val_loss' reached 0.20080 (best 0.20080), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.201
# Epoch 13, global step 14: 'val_loss' reached 0.20064 (best 0.20064), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 14, global step 15: 'val_loss' reached 0.20048 (best 0.20048), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 15, global step 16: 'val_loss' reached 0.20034 (best 0.20034), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 16, global step 17: 'val_loss' reached 0.20021 (best 0.20021), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 17, global step 18: 'val_loss' reached 0.20010 (best 0.20010), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 18, global step 19: 'val_loss' reached 0.19999 (best 0.19999), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 19, global step 20: 'val_loss' reached 0.19988 (best 0.19988), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 20, global step 21: 'val_loss' reached 0.19978 (best 0.19978), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 21, global step 22: 'val_loss' reached 0.19969 (best 0.19969), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 22, global step 23: 'val_loss' reached 0.19960 (best 0.19960), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.200
# Epoch 23, global step 24: 'val_loss' reached 0.19952 (best 0.19952), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 24, global step 25: 'val_loss' reached 0.19943 (best 0.19943), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 25, global step 26: 'val_loss' reached 0.19935 (best 0.19935), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 26, global step 27: 'val_loss' reached 0.19925 (best 0.19925), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 27, global step 28: 'val_loss' reached 0.19914 (best 0.19914), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 28, global step 29: 'val_loss' reached 0.19902 (best 0.19902), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 29, global step 30: 'val_loss' reached 0.19889 (best 0.19889), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 30, global step 31: 'val_loss' reached 0.19878 (best 0.19878), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 31, global step 32: 'val_loss' reached 0.19867 (best 0.19867), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.199
# Epoch 32, global step 33: 'val_loss' reached 0.19856 (best 0.19856), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 33, global step 34: 'val_loss' reached 0.19845 (best 0.19845), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 34, global step 35: 'val_loss' reached 0.19833 (best 0.19833), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 35, global step 36: 'val_loss' reached 0.19822 (best 0.19822), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 36, global step 37: 'val_loss' reached 0.19810 (best 0.19810), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 37, global step 38: 'val_loss' reached 0.19799 (best 0.19799), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 38, global step 39: 'val_loss' reached 0.19790 (best 0.19790), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 39, global step 40: 'val_loss' reached 0.19781 (best 0.19781), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 40, global step 41: 'val_loss' reached 0.19772 (best 0.19772), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 41, global step 42: 'val_loss' reached 0.19765 (best 0.19765), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 42, global step 43: 'val_loss' reached 0.19758 (best 0.19758), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.198
# Epoch 43, global step 44: 'val_loss' reached 0.19751 (best 0.19751), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 44, global step 45: 'val_loss' reached 0.19745 (best 0.19745), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 45, global step 46: 'val_loss' reached 0.19739 (best 0.19739), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 46, global step 47: 'val_loss' reached 0.19733 (best 0.19733), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 47, global step 48: 'val_loss' reached 0.19728 (best 0.19728), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 48, global step 49: 'val_loss' reached 0.19723 (best 0.19723), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 49, global step 50: 'val_loss' reached 0.19719 (best 0.19719), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 50, global step 51: 'val_loss' reached 0.19714 (best 0.19714), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 51, global step 52: 'val_loss' reached 0.19708 (best 0.19708), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 52, global step 53: 'val_loss' reached 0.19701 (best 0.19701), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 53, global step 54: 'val_loss' reached 0.19694 (best 0.19694), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 54, global step 55: 'val_loss' reached 0.19686 (best 0.19686), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 55, global step 56: 'val_loss' reached 0.19677 (best 0.19677), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 56, global step 57: 'val_loss' reached 0.19669 (best 0.19669), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 57, global step 58: 'val_loss' reached 0.19661 (best 0.19661), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.197
# Epoch 58, global step 59: 'val_loss' reached 0.19653 (best 0.19653), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 59, global step 60: 'val_loss' reached 0.19644 (best 0.19644), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 60, global step 61: 'val_loss' reached 0.19636 (best 0.19636), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 61, global step 62: 'val_loss' reached 0.19628 (best 0.19628), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 62, global step 63: 'val_loss' reached 0.19621 (best 0.19621), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 63, global step 64: 'val_loss' reached 0.19613 (best 0.19613), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 64, global step 65: 'val_loss' reached 0.19605 (best 0.19605), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 65, global step 66: 'val_loss' reached 0.19598 (best 0.19598), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 66, global step 67: 'val_loss' reached 0.19590 (best 0.19590), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 67, global step 68: 'val_loss' reached 0.19582 (best 0.19582), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 68, global step 69: 'val_loss' reached 0.19573 (best 0.19573), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 69, global step 70: 'val_loss' reached 0.19564 (best 0.19564), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.196
# Epoch 70, global step 71: 'val_loss' reached 0.19555 (best 0.19555), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 71, global step 72: 'val_loss' reached 0.19545 (best 0.19545), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 72, global step 73: 'val_loss' reached 0.19536 (best 0.19536), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 73, global step 74: 'val_loss' reached 0.19525 (best 0.19525), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 74, global step 75: 'val_loss' reached 0.19516 (best 0.19516), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 75, global step 76: 'val_loss' reached 0.19507 (best 0.19507), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 76, global step 77: 'val_loss' reached 0.19499 (best 0.19499), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 77, global step 78: 'val_loss' reached 0.19490 (best 0.19490), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 78, global step 79: 'val_loss' reached 0.19482 (best 0.19482), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 79, global step 80: 'val_loss' reached 0.19474 (best 0.19474), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 80, global step 81: 'val_loss' reached 0.19472 (best 0.19472), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 81, global step 82: 'val_loss' reached 0.19470 (best 0.19470), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 82, global step 83: 'val_loss' reached 0.19469 (best 0.19469), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 83, global step 84: 'val_loss' reached 0.19467 (best 0.19467), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 84, global step 85: 'val_loss' reached 0.19465 (best 0.19465), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 85, global step 86: 'val_loss' reached 0.19463 (best 0.19463), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 86, global step 87: 'val_loss' reached 0.19461 (best 0.19461), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 87, global step 88: 'val_loss' reached 0.19459 (best 0.19459), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 88, global step 89: 'val_loss' reached 0.19457 (best 0.19457), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 89, global step 90: 'val_loss' reached 0.19455 (best 0.19455), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 90, global step 91: 'val_loss' reached 0.19454 (best 0.19454), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.195
# Epoch 91, global step 92: 'val_loss' reached 0.19452 (best 0.19452), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.194
# Epoch 92, global step 93: 'val_loss' reached 0.19450 (best 0.19450), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.194
# Epoch 93, global step 94: 'val_loss' reached 0.19448 (best 0.19448), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.194
# Epoch 94, global step 95: 'val_loss' reached 0.19446 (best 0.19446), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.194
# Epoch 95, global step 96: 'val_loss' reached 0.19444 (best 0.19444), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.194
# Epoch 96, global step 97: 'val_loss' reached 0.19442 (best 0.19442), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.194
# Epoch 97, global step 98: 'val_loss' reached 0.19440 (best 0.19440), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.194
# Epoch 98, global step 99: 'val_loss' reached 0.19438 (best 0.19438), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.194
# Epoch 99, global step 100: 'val_loss' reached 0.19436 (best 0.19436), saving model to '/home/nikolenko/work/gat/best_model.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: tb_logs/KAN_fold_2
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type  | Params
# -----------------------------------------
# 0 | model_backbone | Model | 2.3 M
# -----------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.096     Total estimated model params size (MB)
# Время обучения fold 1: 0:02:34
# Fold 2/5
# Metric val_loss improved. New best score: 0.175
# Epoch 0, global step 1: 'val_loss' reached 0.17494 (best 0.17494), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.175
# Epoch 1, global step 2: 'val_loss' reached 0.17484 (best 0.17484), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.175
# Epoch 2, global step 3: 'val_loss' reached 0.17479 (best 0.17479), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.175
# Epoch 3, global step 4: 'val_loss' reached 0.17468 (best 0.17468), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.175
# Epoch 4, global step 5: 'val_loss' reached 0.17461 (best 0.17461), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 5, global step 6: 'val_loss' reached 0.17450 (best 0.17450), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 6, global step 7: 'val_loss' reached 0.17441 (best 0.17441), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 7, global step 8: 'val_loss' reached 0.17429 (best 0.17429), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 8, global step 9: 'val_loss' reached 0.17419 (best 0.17419), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 9, global step 10: 'val_loss' reached 0.17407 (best 0.17407), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 10, global step 11: 'val_loss' reached 0.17398 (best 0.17398), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 11, global step 12: 'val_loss' reached 0.17386 (best 0.17386), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 12, global step 13: 'val_loss' reached 0.17376 (best 0.17376), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 13, global step 14: 'val_loss' reached 0.17363 (best 0.17363), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.174
# Epoch 14, global step 15: 'val_loss' reached 0.17352 (best 0.17352), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.173
# Epoch 15, global step 16: 'val_loss' reached 0.17338 (best 0.17338), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.173
# Epoch 16, global step 17: 'val_loss' reached 0.17326 (best 0.17326), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.173
# Epoch 17, global step 18: 'val_loss' reached 0.17313 (best 0.17313), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.173
# Epoch 18, global step 19: 'val_loss' reached 0.17301 (best 0.17301), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.173
# Epoch 19, global step 20: 'val_loss' reached 0.17288 (best 0.17288), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.173
# Epoch 20, global step 21: 'val_loss' reached 0.17277 (best 0.17277), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.173
# Epoch 21, global step 22: 'val_loss' reached 0.17264 (best 0.17264), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.173
# Epoch 22, global step 23: 'val_loss' reached 0.17254 (best 0.17254), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.172
# Epoch 23, global step 24: 'val_loss' reached 0.17241 (best 0.17241), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.172
# Epoch 24, global step 25: 'val_loss' reached 0.17232 (best 0.17232), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.172
# Epoch 25, global step 26: 'val_loss' reached 0.17218 (best 0.17218), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.172
# Epoch 26, global step 27: 'val_loss' reached 0.17209 (best 0.17209), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.172
# Epoch 27, global step 28: 'val_loss' reached 0.17196 (best 0.17196), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.172
# Epoch 28, global step 29: 'val_loss' reached 0.17186 (best 0.17186), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.172
# Epoch 29, global step 30: 'val_loss' reached 0.17171 (best 0.17171), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.172
# Epoch 30, global step 31: 'val_loss' reached 0.17160 (best 0.17160), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.171
# Epoch 31, global step 32: 'val_loss' reached 0.17145 (best 0.17145), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.171
# Epoch 32, global step 33: 'val_loss' reached 0.17133 (best 0.17133), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.171
# Epoch 33, global step 34: 'val_loss' reached 0.17118 (best 0.17118), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.171
# Epoch 34, global step 35: 'val_loss' reached 0.17106 (best 0.17106), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.171
# Epoch 35, global step 36: 'val_loss' reached 0.17090 (best 0.17090), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.171
# Epoch 36, global step 37: 'val_loss' reached 0.17076 (best 0.17076), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.171
# Epoch 37, global step 38: 'val_loss' reached 0.17059 (best 0.17059), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.170
# Epoch 38, global step 39: 'val_loss' reached 0.17043 (best 0.17043), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.170
# Epoch 39, global step 40: 'val_loss' reached 0.17025 (best 0.17025), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.170
# Epoch 40, global step 41: 'val_loss' reached 0.17007 (best 0.17007), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.170
# Epoch 41, global step 42: 'val_loss' reached 0.16987 (best 0.16987), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.170
# Epoch 42, global step 43: 'val_loss' reached 0.16967 (best 0.16967), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.169
# Epoch 43, global step 44: 'val_loss' reached 0.16948 (best 0.16948), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.169
# Epoch 44, global step 45: 'val_loss' reached 0.16929 (best 0.16929), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.169
# Epoch 45, global step 46: 'val_loss' reached 0.16909 (best 0.16909), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.169
# Epoch 46, global step 47: 'val_loss' reached 0.16891 (best 0.16891), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.169
# Epoch 47, global step 48: 'val_loss' reached 0.16871 (best 0.16871), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.169
# Epoch 48, global step 49: 'val_loss' reached 0.16853 (best 0.16853), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.168
# Epoch 49, global step 50: 'val_loss' reached 0.16834 (best 0.16834), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.168
# Epoch 50, global step 51: 'val_loss' reached 0.16815 (best 0.16815), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.168
# Epoch 51, global step 52: 'val_loss' reached 0.16796 (best 0.16796), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.168
# Epoch 52, global step 53: 'val_loss' reached 0.16776 (best 0.16776), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.168
# Epoch 53, global step 54: 'val_loss' reached 0.16755 (best 0.16755), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.167
# Epoch 54, global step 55: 'val_loss' reached 0.16733 (best 0.16733), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.167
# Epoch 55, global step 56: 'val_loss' reached 0.16712 (best 0.16712), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.167
# Epoch 56, global step 57: 'val_loss' reached 0.16688 (best 0.16688), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.167
# Epoch 57, global step 58: 'val_loss' reached 0.16665 (best 0.16665), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.166
# Epoch 58, global step 59: 'val_loss' reached 0.16640 (best 0.16640), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.166
# Epoch 59, global step 60: 'val_loss' reached 0.16615 (best 0.16615), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.166
# Epoch 60, global step 61: 'val_loss' reached 0.16587 (best 0.16587), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.166
# Epoch 61, global step 62: 'val_loss' reached 0.16563 (best 0.16563), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.165
# Epoch 62, global step 63: 'val_loss' reached 0.16533 (best 0.16533), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.165
# Epoch 63, global step 64: 'val_loss' reached 0.16507 (best 0.16507), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.165
# Epoch 64, global step 65: 'val_loss' reached 0.16476 (best 0.16476), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.164
# Epoch 65, global step 66: 'val_loss' reached 0.16447 (best 0.16447), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.164
# Epoch 66, global step 67: 'val_loss' reached 0.16414 (best 0.16414), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.164
# Epoch 67, global step 68: 'val_loss' reached 0.16384 (best 0.16384), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.164
# Epoch 68, global step 69: 'val_loss' reached 0.16350 (best 0.16350), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.163
# Epoch 69, global step 70: 'val_loss' reached 0.16318 (best 0.16318), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.163
# Epoch 70, global step 71: 'val_loss' reached 0.16283 (best 0.16283), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.162
# Epoch 71, global step 72: 'val_loss' reached 0.16249 (best 0.16249), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.162
# Epoch 72, global step 73: 'val_loss' reached 0.16212 (best 0.16212), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.162
# Epoch 73, global step 74: 'val_loss' reached 0.16178 (best 0.16178), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.161
# Epoch 74, global step 75: 'val_loss' reached 0.16139 (best 0.16139), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.161
# Epoch 75, global step 76: 'val_loss' reached 0.16103 (best 0.16103), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.161
# Epoch 76, global step 77: 'val_loss' reached 0.16063 (best 0.16063), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.160
# Epoch 77, global step 78: 'val_loss' reached 0.16025 (best 0.16025), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.160
# Epoch 78, global step 79: 'val_loss' reached 0.15984 (best 0.15984), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 79, global step 80: 'val_loss' reached 0.15945 (best 0.15945), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 80, global step 81: 'val_loss' reached 0.15935 (best 0.15935), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 81, global step 82: 'val_loss' reached 0.15926 (best 0.15926), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 82, global step 83: 'val_loss' reached 0.15917 (best 0.15917), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 83, global step 84: 'val_loss' reached 0.15908 (best 0.15908), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 84, global step 85: 'val_loss' reached 0.15900 (best 0.15900), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 85, global step 86: 'val_loss' reached 0.15891 (best 0.15891), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 86, global step 87: 'val_loss' reached 0.15882 (best 0.15882), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 87, global step 88: 'val_loss' reached 0.15873 (best 0.15873), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 88, global step 89: 'val_loss' reached 0.15864 (best 0.15864), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.159
# Epoch 89, global step 90: 'val_loss' reached 0.15855 (best 0.15855), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 90, global step 91: 'val_loss' reached 0.15846 (best 0.15846), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 91, global step 92: 'val_loss' reached 0.15837 (best 0.15837), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 92, global step 93: 'val_loss' reached 0.15828 (best 0.15828), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 93, global step 94: 'val_loss' reached 0.15818 (best 0.15818), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 94, global step 95: 'val_loss' reached 0.15809 (best 0.15809), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 95, global step 96: 'val_loss' reached 0.15800 (best 0.15800), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 96, global step 97: 'val_loss' reached 0.15790 (best 0.15790), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 97, global step 98: 'val_loss' reached 0.15781 (best 0.15781), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 98, global step 99: 'val_loss' reached 0.15772 (best 0.15772), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.158
# Epoch 99, global step 100: 'val_loss' reached 0.15762 (best 0.15762), saving model to '/home/nikolenko/work/gat/best_model-v1.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: tb_logs/KAN_fold_3
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type  | Params
# -----------------------------------------
# 0 | model_backbone | Model | 2.3 M
# -----------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.096     Total estimated model params size (MB)
# Время обучения fold 2: 0:02:42
# Fold 3/5
# Metric val_loss improved. New best score: 0.180
# Epoch 0, global step 1: 'val_loss' reached 0.17987 (best 0.17987), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.179
# Epoch 1, global step 2: 'val_loss' reached 0.17925 (best 0.17925), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.179
# Epoch 2, global step 3: 'val_loss' reached 0.17905 (best 0.17905), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.178
# Epoch 3, global step 4: 'val_loss' reached 0.17835 (best 0.17835), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.178
# Epoch 4, global step 5: 'val_loss' reached 0.17798 (best 0.17798), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.177
# Epoch 5, global step 6: 'val_loss' reached 0.17731 (best 0.17731), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.177
# Epoch 6, global step 7: 'val_loss' reached 0.17684 (best 0.17684), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.176
# Epoch 7, global step 8: 'val_loss' reached 0.17614 (best 0.17614), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.176
# Epoch 8, global step 9: 'val_loss' reached 0.17561 (best 0.17561), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.175
# Epoch 9, global step 10: 'val_loss' reached 0.17485 (best 0.17485), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.174
# Epoch 10, global step 11: 'val_loss' reached 0.17428 (best 0.17428), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.173
# Epoch 11, global step 12: 'val_loss' reached 0.17346 (best 0.17346), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.173
# Epoch 12, global step 13: 'val_loss' reached 0.17285 (best 0.17285), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.172
# ...
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.103
# Epoch 90, global step 91: 'val_loss' reached 0.10294 (best 0.10294), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.103
# Epoch 91, global step 92: 'val_loss' reached 0.10277 (best 0.10277), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.103
# Epoch 92, global step 93: 'val_loss' reached 0.10260 (best 0.10260), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.102
# Epoch 93, global step 94: 'val_loss' reached 0.10243 (best 0.10243), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.102
# Epoch 94, global step 95: 'val_loss' reached 0.10225 (best 0.10225), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.102
# Epoch 95, global step 96: 'val_loss' reached 0.10208 (best 0.10208), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.102
# Epoch 96, global step 97: 'val_loss' reached 0.10190 (best 0.10190), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.102
# Epoch 97, global step 98: 'val_loss' reached 0.10173 (best 0.10173), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.102
# Epoch 98, global step 99: 'val_loss' reached 0.10155 (best 0.10155), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.101
# Epoch 99, global step 100: 'val_loss' reached 0.10137 (best 0.10137), saving model to '/home/nikolenko/work/gat/best_model-v2.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: tb_logs/KAN_fold_4
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type  | Params
# -----------------------------------------
# 0 | model_backbone | Model | 2.3 M
# -----------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.096     Total estimated model params size (MB)
# Время обучения fold 3: 0:02:32
# Fold 4/5
# Metric val_loss improved. New best score: 0.095
# Epoch 0, global step 1: 'val_loss' reached 0.09542 (best 0.09542), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.095
# Epoch 1, global step 2: 'val_loss' reached 0.09518 (best 0.09518), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 2, global step 3: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.094
# Epoch 3, global step 4: 'val_loss' reached 0.09435 (best 0.09435), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 4, global step 5: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.094
# Epoch 5, global step 6: 'val_loss' reached 0.09359 (best 0.09359), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 6, global step 7: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.093
# Epoch 7, global step 8: 'val_loss' reached 0.09291 (best 0.09291), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 8, global step 9: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.092
# Epoch 9, global step 10: 'val_loss' reached 0.09229 (best 0.09229), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 10, global step 11: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.092
# Epoch 11, global step 12: 'val_loss' reached 0.09174 (best 0.09174), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 12, global step 13: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.091
# Epoch 13, global step 14: 'val_loss' reached 0.09123 (best 0.09123), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 14, global step 15: 'val_loss' was not in top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.091
# Epoch 15, global step 16: 'val_loss' reached 0.09074 (best 0.09074), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 16, global step 17: 'val_loss' was not in top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.090
# Epoch 17, global step 18: 'val_loss' reached 0.09027 (best 0.09027), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 18, global step 19: 'val_loss' was not in top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.090
# Epoch 19, global step 20: 'val_loss' reached 0.08980 (best 0.08980), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 20, global step 21: 'val_loss' was not in top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.089
# Epoch 21, global step 22: 'val_loss' reached 0.08932 (best 0.08932), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 22, global step 23: 'val_loss' was not in top 1
# Metric val_loss improved by 0.000 >= min_delta = 0.0. New best score: 0.089
# Epoch 23, global step 24: 'val_loss' reached 0.08884 (best 0.08884), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 24, global step 25: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.088
# Epoch 25, global step 26: 'val_loss' reached 0.08833 (best 0.08833), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 26, global step 27: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.088
# Epoch 27, global step 28: 'val_loss' reached 0.08779 (best 0.08779), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 28, global step 29: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.087
# Epoch 29, global step 30: 'val_loss' reached 0.08723 (best 0.08723), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 30, global step 31: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.087
# Epoch 31, global step 32: 'val_loss' reached 0.08665 (best 0.08665), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 32, global step 33: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.086
# Epoch 33, global step 34: 'val_loss' reached 0.08603 (best 0.08603), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 34, global step 35: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.085
# Epoch 35, global step 36: 'val_loss' reached 0.08539 (best 0.08539), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 36, global step 37: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.085
# Epoch 37, global step 38: 'val_loss' reached 0.08472 (best 0.08472), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 38, global step 39: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.084
# Epoch 39, global step 40: 'val_loss' reached 0.08404 (best 0.08404), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 40, global step 41: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.083
# Epoch 41, global step 42: 'val_loss' reached 0.08334 (best 0.08334), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 42, global step 43: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.083
# Epoch 43, global step 44: 'val_loss' reached 0.08263 (best 0.08263), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 44, global step 45: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.082
# Epoch 45, global step 46: 'val_loss' reached 0.08191 (best 0.08191), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 46, global step 47: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.081
# Epoch 47, global step 48: 'val_loss' reached 0.08117 (best 0.08117), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 48, global step 49: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.080
# Epoch 49, global step 50: 'val_loss' reached 0.08044 (best 0.08044), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 50, global step 51: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.080
# Epoch 51, global step 52: 'val_loss' reached 0.07970 (best 0.07970), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 52, global step 53: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.079
# Epoch 53, global step 54: 'val_loss' reached 0.07896 (best 0.07896), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 54, global step 55: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.078
# Epoch 55, global step 56: 'val_loss' reached 0.07824 (best 0.07824), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 56, global step 57: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.078
# Epoch 57, global step 58: 'val_loss' reached 0.07753 (best 0.07753), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 58, global step 59: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.077
# Epoch 59, global step 60: 'val_loss' reached 0.07682 (best 0.07682), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 60, global step 61: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.076
# Epoch 61, global step 62: 'val_loss' reached 0.07613 (best 0.07613), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 62, global step 63: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.075
# Epoch 63, global step 64: 'val_loss' reached 0.07546 (best 0.07546), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 64, global step 65: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.075
# Epoch 65, global step 66: 'val_loss' reached 0.07479 (best 0.07479), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 66, global step 67: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.074
# Epoch 67, global step 68: 'val_loss' reached 0.07414 (best 0.07414), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 68, global step 69: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.073
# Epoch 69, global step 70: 'val_loss' reached 0.07350 (best 0.07350), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 70, global step 71: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.073
# Epoch 71, global step 72: 'val_loss' reached 0.07287 (best 0.07287), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 72, global step 73: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.072
# Epoch 73, global step 74: 'val_loss' reached 0.07226 (best 0.07226), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 74, global step 75: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.072
# Epoch 75, global step 76: 'val_loss' reached 0.07167 (best 0.07167), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 76, global step 77: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.071
# Epoch 77, global step 78: 'val_loss' reached 0.07110 (best 0.07110), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 78, global step 79: 'val_loss' was not in top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.071
# Epoch 79, global step 80: 'val_loss' reached 0.07054 (best 0.07054), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Metric val_loss improved by 0.001 >= min_delta = 0.0. New best score: 0.070
# Epoch 80, global step 81: 'val_loss' reached 0.06996 (best 0.06996), saving model to '/home/nikolenko/work/gat/best_model-v3.ckpt' as top 1
# Epoch 81, global step 82: 'val_loss' was not in top 1
# Epoch 82, global step 83: 'val_loss' was not in top 1
# Epoch 83, global step 84: 'val_loss' was not in top 1
# Epoch 84, global step 85: 'val_loss' was not in top 1
# Monitored metric val_loss did not improve in the last 5 records. Best score: 0.070. Signaling Trainer to stop.
# Epoch 85, global step 86: 'val_loss' was not in top 1
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: tb_logs/KAN_fold_5
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type  | Params
# -----------------------------------------
# 0 | model_backbone | Model | 2.3 M
# -----------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.096     Total estimated model params size (MB)
# Время обучения fold 4: 0:01:52
# Fold 5/5
# Metric val_loss improved. New best score: 0.080
# Epoch 0, global step 1: 'val_loss' reached 0.07979 (best 0.07979), saving model to '/home/nikolenko/work/gat/best_model-v4.ckpt' as top 1
# Metric val_loss improved by 0.007 >= min_delta = 0.0. New best score: 0.072
# Epoch 1, global step 2: 'val_loss' reached 0.07229 (best 0.07229), saving model to '/home/nikolenko/work/gat/best_model-v4.ckpt' as top 1
# Epoch 2, global step 3: 'val_loss' was not in top 1
# Epoch 3, global step 4: 'val_loss' was not in top 1
# Epoch 4, global step 5: 'val_loss' was not in top 1
# Epoch 5, global step 6: 'val_loss' was not in top 1
# Monitored metric val_loss did not improve in the last 5 records. Best score: 0.072. Signaling Trainer to stop.
# Epoch 6, global step 7: 'val_loss' was not in top 1
# Время обучения fold 5: 0:00:08
# Результаты кросс-валидации:
# Fold 1: Валид. ошибка (RMSE) = 0.1944
# Fold 2: Валид. ошибка (RMSE) = 0.1576
# Fold 3: Валид. ошибка (RMSE) = 0.1014
# Fold 4: Валид. ошибка (RMSE) = 0.0707
# Fold 5: Валид. ошибка (RMSE) = 0.0763
# Средняя валид. ошибка (RMSE): 0.1201
# Лучший чекпоинт модели сохранен по пути: /home/nikolenko/work/gat/best_model-v3.ckpt

# %% [markdown]
# ## Evaluate the Final Model

# %%
# Evaluate the final model on the entire dataset
evaluate_model_full(best_model, dataset, batch_size, num_workers)
